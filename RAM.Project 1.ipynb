# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import requests
# %matplotlib inline

# %% [markdown]
# df1=pd.read_csv('bom.movie_gross.csv.gz')

# %%
# to read the movie gross data and loading data in df1
df1=pd.read_csv('bom.movie_gross.csv.gz')

# %%
#to know what data and datatypes present in the df1 and also to know the null values 
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3387 entries, 0 to 3386
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   title           3387 non-null   object
#  1   studio          3382 non-null   object
#  2   domestic_gross  3359 non-null   float64
#  3   foreign_gross   2037 non-null   object
#  4   year            3387 non-null   int64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 132.4+ KB

# %%
df1
# Out:
#                                             title      studio  domestic_gross  \
# 0                                     Toy Story 3          BV     415000000.0
# 1                      Alice in Wonderland (2010)          BV     334200000.0
# 2     Harry Potter and the Deathly Hallows Part 1          WB     296000000.0
# 3                                       Inception          WB     292600000.0
# 4                             Shrek Forever After        P/DW     238700000.0
# ...                                           ...         ...             ...
# 3382                                    The Quake       Magn.          6200.0
# 3383                  Edward II (2018 re-release)          FM          4800.0
# 3384                                     El Pacto        Sony          2500.0
# 3385                                     The Swan  Synergetic          2400.0
# 3386                            An Actor Prepares       Grav.          1700.0
#
#      foreign_gross  year
# ...

# %%
#to read the data in titlebasics file
df2=df_title_basics=pd.read_csv('imdb.title.basics.csv.gz')

# %%
df2
# Out:
#            tconst                                primary_title  \
# 0       tt0063540                                    Sunghursh
# 1       tt0066787              One Day Before the Rainy Season
# 2       tt0069049                   The Other Side of the Wind
# 3       tt0069204                              Sabse Bada Sukh
# 4       tt0100275                     The Wandering Soap Opera
# ...           ...                                          ...
# 146139  tt9916538                          Kuambil Lagi Hatiku
# 146140  tt9916622  Rodolpho Teóphilo - O Legado de um Pioneiro
# 146141  tt9916706                              Dankyavar Danka
# 146142  tt9916730                                       6 Gunn
# 146143  tt9916754               Chico Albuquerque - Revelações
#
#                                      original_title  start_year  \
# 0                                         Sunghursh        2013
# 1                                   Ashad Ka Ek Din        2019
# ...

# %%
#to read the data in title ratings file
df3=df_title_ratings=pd.read_csv('imdb.title.ratings.csv.gz')

# %%
df3
# Out:
#            tconst  averagerating  numvotes
# 0      tt10356526            8.3        31
# 1      tt10384606            8.9       559
# 2       tt1042974            6.4        20
# 3       tt1043726            4.2     50352
# 4       tt1060240            6.5        21
# ...           ...            ...       ...
# 73851   tt9805820            8.1        25
# 73852   tt9844256            7.5        24
# 73853   tt9851050            4.7        14
# 73854   tt9886934            7.0         5
# 73855   tt9894098            6.3       128
#
# [73856 rows x 3 columns]

# %%
#to read the data in movie budgets file
df4=df_movie_budget=pd.read_csv('tn.movie_budgets.csv.gz')

# %%
df4
# Out:
#       id  release_date                                        movie  \
# 0      1  Dec 18, 2009                                       Avatar
# 1      2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2      3   Jun 7, 2019                                 Dark Phoenix
# 3      4   May 1, 2015                      Avengers: Age of Ultron
# 4      5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
# ...   ..           ...                                          ...
# 5777  78  Dec 31, 2018                                       Red 11
# 5778  79   Apr 2, 1999                                    Following
# 5779  80  Jul 13, 2005                Return to the Land of Wonders
# 5780  81  Sep 29, 2015                         A Plague So Pleasant
# 5781  82   Aug 5, 2005                            My Date With Drew
#
#      production_budget domestic_gross worldwide_gross
# 0         $425,000,000   $760,507,625  $2,776,345,279
# ...

# %%
# generating descriptive statistics for domestic box office values
df4['production_budget'].describe()
# Out:
# count            5782
# unique            509
# top       $20,000,000
# freq              231
# Name: production_budget, dtype: object

# %%
#merging the data in 2 files by using merge method with the help of comon column present in both the tables
#merge_df=pd.merge(df2,df3,on='tconst',how='inner')

dfratings=df2.merge(df3,on='tconst',how='inner')

# %%
dfratings
# Out:
#           tconst                    primary_title              original_title  \
# 0      tt0063540                        Sunghursh                   Sunghursh
# 1      tt0066787  One Day Before the Rainy Season             Ashad Ka Ek Din
# 2      tt0069049       The Other Side of the Wind  The Other Side of the Wind
# 3      tt0069204                  Sabse Bada Sukh             Sabse Bada Sukh
# 4      tt0100275         The Wandering Soap Opera       La Telenovela Errante
# ...          ...                              ...                         ...
# 73851  tt9913084                 Diabolik sono io            Diabolik sono io
# 73852  tt9914286                Sokagin Çocuklari           Sokagin Çocuklari
# 73853  tt9914642                        Albatross                   Albatross
# 73854  tt9914942       La vida sense la Sara Amat  La vida sense la Sara Amat
# 73855  tt9916160                       Drømmeland                  Drømmeland
#
# ...

# %%
#to count the total number of genres
dfratings['genres'].value_counts()
# Out:
# genres
# Drama                        11612
# Documentary                  10313
# Comedy                        5613
# Horror                        2692
# Comedy,Drama                  2617
#                              ...
# Sport,Thriller                   1
# Comedy,Sport,Western             1
# Action,Music                     1
# Comedy,Sci-Fi,Western            1
# Documentary,Family,Sci-Fi        1
# Name: count, Length: 923, dtype: int64

# %%
#to know the total number of entries 
#all the info in df3 is present because of inner join
dfratings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 73856 entries, 0 to 73855
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   tconst           73856 non-null  object
#  1   primary_title    73856 non-null  object
#  2   original_title   73856 non-null  object
#  3   start_year       73856 non-null  int64
#  4   runtime_minutes  66236 non-null  float64
#  5   genres           73052 non-null  object
#  6   averagerating    73856 non-null  float64
#  7   numvotes         73856 non-null  int64
# dtypes: float64(2), int64(2), object(4)
# memory usage: 4.5+ MB

# %%
#data filtered from 2011 to 2014 
dfratinginfo2014=df5=dfratings[(dfratings['start_year'] >= 2011) & (dfratings['start_year'] <= 2014)][['averagerating', 'genres', 'numvotes', 'start_year']]

# %%
df5
# Out:
#        averagerating                   genres  numvotes  start_year
# 0                7.0       Action,Crime,Drama        77        2013
# 9                7.6              Documentary        53        2013
# 12               7.8  Animation,Drama,History       584        2011
# 15               4.0            Drama,Mystery        12        2011
# 16               1.9  Action,Animation,Comedy      8248        2012
# ...              ...                      ...       ...         ...
# 73264            6.9       Comedy,Drama,Music         9        2011
# 73288            5.3                   Horror        23        2014
# 73331            7.3                   Comedy         6        2014
# 73373            5.5                    Drama         6        2014
# 73596            7.8                      NaN         5        2012
#
# [31430 rows x 4 columns]

# %%
#more than 1000 votings is ideal to consider to bring the good insights
df_voting_counts1000=df6=df5[(df5['numvotes'] >= 1000)]

# %%
df6
# Out:
#        averagerating                      genres  numvotes  start_year
# 16               1.9     Action,Animation,Comedy      8248        2012
# 27               6.6                    Thriller      1053        2012
# 32               3.9                Drama,Horror      2328        2011
# 41               6.1     Adventure,Drama,Romance     37886        2012
# 47               7.3      Adventure,Comedy,Drama    275300        2013
# ...              ...                         ...       ...         ...
# 44778            3.6                      Comedy      1477        2014
# 44883            6.7          Action,Crime,Drama      1089        2014
# 48306            9.2  Comedy,Documentary,History      1015        2014
# 53307            7.8        Drama,Horror,Mystery      6415        2014
# 58444            8.8       Action,Crime,Thriller      3406        2011
#
# [4317 rows x 4 columns]

# %%
#to show the first ten movie ratings morethan 1000
df6.head(10)
# Out:
#     averagerating                      genres  numvotes  start_year
# 16            1.9     Action,Animation,Comedy      8248        2012
# 27            6.6                    Thriller      1053        2012
# 32            3.9                Drama,Horror      2328        2011
# 41            6.1     Adventure,Drama,Romance     37886        2012
# 47            7.3      Adventure,Comedy,Drama    275300        2013
# 51            6.5          Action,Crime,Drama    105116        2014
# 54            6.2                Comedy,Drama     94787        2011
# 56            6.0  Adventure,Animation,Comedy     49550        2011
# 58            5.1               Comedy,Family     28570        2012
# 63            6.6     Action,Adventure,Sci-Fi    241792        2012

# %%
#calculating the genre in average by using mean and list top 10

df_grouped2014=df6.groupby('genres')['averagerating'].mean()
df_sorted2014 = df_grouped2014.sort_values(ascending=False)
df_sorted2014a = df_sorted2014.reset_index()
df_sorted2014a.columns = ['genres', 'averagerating']
df_sorted2014a.head(10)
# Out:
#                            genres  averagerating
# 0                         Musical            8.6
# 1          Adventure,Drama,Sci-Fi            8.6
# 2               Animation,History            8.3
# 3           Drama,Family,Thriller            8.3
# 4      Adventure,Biography,Comedy            8.3
# 5     Adventure,Documentary,Sport            8.3
# 6       Documentary,History,Music            8.3
# 7                             War            8.2
# 8              Documentary,Family            8.1
# 9  Biography,Documentary,Thriller            8.1

# %%
#preparing bar chart for ploting and shows the comparisons among discreet categories

df_sorted2014a.head(10).set_index('genres', inplace=True)
df2014b = df_sorted2014a.head(10)
df2014c = df2014b.sort_values(by='averagerating')

# %%
df2014c
# Out:
#                            genres  averagerating
# 9  Biography,Documentary,Thriller            8.1
# 8              Documentary,Family            8.1
# 7                             War            8.2
# 2               Animation,History            8.3
# 3           Drama,Family,Thriller            8.3
# 4      Adventure,Biography,Comedy            8.3
# 5     Adventure,Documentary,Sport            8.3
# 6       Documentary,History,Music            8.3
# 0                         Musical            8.6
# 1          Adventure,Drama,Sci-Fi            8.6

# %%
#bar char creation in vertical manner
#barh represents in horizontal manner

df2014c.set_index('genres', inplace=True)
df2014c['averagerating'].plot(kind='bar', figsize=(8, 4))
plt.title('Highest Average Rating by Genre 2011-2014',color="red")
plt.xlabel('Genres')
plt.ylabel('Average Rating')
plt.show()

# %%
#drafting the data from 2015-2019
dfratinginfo2019=df7=dfratings[(dfratings['start_year'] >= 2015) & (dfratings['start_year'] <= 2019)][['averagerating', 'genres', 'numvotes', 'start_year']]

# %%
df7
# Out:
#        averagerating                genres  numvotes  start_year
# 1                7.2       Biography,Drama        43        2019
# 2                6.9                 Drama      4517        2018
# 3                6.1          Comedy,Drama        13        2018
# 4                6.5  Comedy,Drama,Fantasy       119        2017
# 5                4.1       Horror,Thriller        32        2017
# ...              ...                   ...       ...         ...
# 73851            6.2           Documentary         6        2019
# 73852            8.7          Drama,Family       136        2019
# 73853            8.5           Documentary         8        2017
# 73854            6.6                   NaN         5        2019
# 73855            6.5           Documentary        11        2019
#
# [35634 rows x 4 columns]

# %%
#more than 1000 votings is ideal to consider to bring the good insights
df_voting_counts1000=df8=df7[(df7['numvotes'] >= 1000)]

# %%
df8
# Out:
#        averagerating                 genres  numvotes  start_year
# 2                6.9                  Drama      4517        2018
# 31               7.1     Action,Crime,Drama     15378        2016
# 44               5.6                 Horror      2420        2017
# 48               4.9  Drama,Sci-Fi,Thriller     14469        2018
# 50               6.4   Comedy,Drama,Romance      6287        2018
# ...              ...                    ...       ...         ...
# 73374            3.7        Biography,Drama      4057        2019
# 73376            2.6          Action,Sci-Fi      1509        2019
# 73388            7.1            Documentary     19632        2019
# 73683            3.1            Documentary      2220        2019
# 73730            4.7                 Action      1214        2019
#
# [4375 rows x 4 columns]

# %%
df_grouped2019 = df8.groupby('genres')['averagerating'].mean()
df_sorted2019 = df_grouped2019.sort_values(ascending=False)
df_sorted2019a = df_sorted2019.reset_index()
df_sorted2019a.columns = ['genres', 'averagerating']
df_sorted2019a.head(10)
# Out:
#                             genres  averagerating
# 0  Adventure,Biography,Documentary           8.85
# 1             Comedy,Fantasy,Music           8.60
# 2             Documentary,Thriller           8.60
# 3               Action,Romance,War           8.50
# 4      Adventure,Documentary,Drama           8.20
# 5    Animation,Documentary,Mystery           8.20
# 6          Documentary,History,War           8.15
# 7       Biography,Documentary,News           8.10
# 8      Biography,Documentary,Drama           8.06
# 9        Documentary,History,Sport           8.05

# %%
df_sorted2019a.head(10).set_index('genres', inplace=True)
df2019b = df_sorted2019a.head(10)
df2019c = df2019b.sort_values(by='averagerating')
df2019c
# Out:
#                             genres  averagerating
# 9        Documentary,History,Sport           8.05
# 8      Biography,Documentary,Drama           8.06
# 7       Biography,Documentary,News           8.10
# 6          Documentary,History,War           8.15
# 4      Adventure,Documentary,Drama           8.20
# 5    Animation,Documentary,Mystery           8.20
# 3               Action,Romance,War           8.50
# 1             Comedy,Fantasy,Music           8.60
# 2             Documentary,Thriller           8.60
# 0  Adventure,Biography,Documentary           8.85

# %%
df2019c.set_index('genres', inplace=True)
df2019c['averagerating'].plot(kind='bar', figsize=(8, 4))
plt.title('Highest Average Rating by Genre 2015-2019')
plt.xlabel('Genres')
plt.ylabel('Average Rating')
plt.show()

# %%
#to read the data in movie budgets file
#df4=df_movie_budget=pd.read_csv('tn.movie_budgets.csv.gz')
#this file is already extracted in the begining

# %%
#replacing integer with string 
dfbudget_domesticgross = df4['domestic_gross'].str.replace('[\$,]', '', regex=True).astype('int64')
dfbudget_worldgross = df4['worldwide_gross'].str.replace('[\$,]', '', regex=True).astype('int64')

# %%
# Caculate total gross
df4['total_gross'] = dfbudget_domesticgross + dfbudget_worldgross

# %%
df4['total_gross']
# Out:
# 0       3536852904
# 1       1286727750
# 2        192524700
# 3       1862019831
# 4       1936903129
#            ...
# 5777             0
# 5778        288977
# 5779          2676
# 5780             0
# 5781        362082
# Name: total_gross, Length: 5782, dtype: int64

# %%
# now Extracting month from the release date by using str.split function
df4['month'] = df4['release_date'].str.split(' ', expand=True)[0].astype(str)
df4['month'] = df4['month'].str.strip()

# %%
#if you run now it will show all the changes made to the actual file
df4
# Out:
#       id  release_date                                        movie  \
# 0      1  Dec 18, 2009                                       Avatar
# 1      2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2      3   Jun 7, 2019                                 Dark Phoenix
# 3      4   May 1, 2015                      Avengers: Age of Ultron
# 4      5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
# ...   ..           ...                                          ...
# 5777  78  Dec 31, 2018                                       Red 11
# 5778  79   Apr 2, 1999                                    Following
# 5779  80  Jul 13, 2005                Return to the Land of Wonders
# 5780  81  Sep 29, 2015                         A Plague So Pleasant
# 5781  82   Aug 5, 2005                            My Date With Drew
#
#      production_budget domestic_gross worldwide_gross  total_gross month
# 0         $425,000,000   $760,507,625  $2,776,345,279   3536852904   Dec
# ...

# %%
# Calculate the average of total gross by each month with mean
df_moviebestmonth = df4.groupby('month')['total_gross'].mean()

# Make the data more understandable
df_moviebestmonth = pd.DataFrame(df_moviebestmonth)
df_moviebestmonth = df_moviebestmonth.reset_index()
df_moviebestmonth.columns = ['month', 'total_gross']
df_moviebestmonth
# Out:
#    month   total_gross
# 0    Apr  8.724866e+07
# 1    Aug  9.314662e+07
# 2    Dec  1.477940e+08
# 3    Feb  1.069592e+08
# 4    Jan  7.051344e+07
# 5    Jul  2.016917e+08
# 6    Jun  2.083509e+08
# 7    Mar  1.192064e+08
# 8    May  2.289660e+08
# 9    Nov  1.939228e+08
# 10   Oct  7.388806e+07
# 11   Sep  6.984357e+07

# %%
# Replace the months in number format for ranking using replace function

df_moviebestmonth['month'] = df_moviebestmonth['month'].replace({'Jan': '1'})
df_moviebestmonth['month'] = df_moviebestmonth['month'].replace({'Feb': '2'})
df_moviebestmonth['month'] = df_moviebestmonth['month'].replace({'Mar': '3'})
df_moviebestmonth['month'] = df_moviebestmonth['month'].replace({'Apr': '4'})
df_moviebestmonth['month'] = df_moviebestmonth['month'].replace({'May': '5'})
df_moviebestmonth['month'] = df_moviebestmonth['month'].replace({'Jun': '6'})
df_moviebestmonth['month'] = df_moviebestmonth['month'].replace({'Jul': '7'})
df_moviebestmonth['month'] = df_moviebestmonth['month'].replace({'Aug': '8'})
df_moviebestmonth['month'] = df_moviebestmonth['month'].replace({'Sep': '9'})
df_moviebestmonth['month'] = df_moviebestmonth['month'].replace({'Oct': '10'})
df_moviebestmonth['month'] = df_moviebestmonth['month'].replace({'Nov': '11'})
df_moviebestmonth['month'] = df_moviebestmonth['month'].replace({'Dec': '12'})
df_moviebestmonth['month'] = df_moviebestmonth['month'].astype(int)
df_moviebestmonth = df_moviebestmonth.sort_values('month')
df_moviebestmonth
# Out:
#     month   total_gross
# 4       1  7.051344e+07
# 3       2  1.069592e+08
# 7       3  1.192064e+08
# 0       4  8.724866e+07
# 8       5  2.289660e+08
# 6       6  2.083509e+08
# 5       7  2.016917e+08
# 1       8  9.314662e+07
# 11      9  6.984357e+07
# 10     10  7.388806e+07
# 9      11  1.939228e+08
# 2      12  1.477940e+08

# %%
#now create the bar chart to compare the gross for each month
df_moviebestmonth.plot.bar(x='month', y='total_gross', title='Average gross for each month')
plt.xticks(rotation=0)
plt.show()

# %%
df4
# Out:
#       id  release_date                                        movie  \
# 0      1  Dec 18, 2009                                       Avatar
# 1      2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2      3   Jun 7, 2019                                 Dark Phoenix
# 3      4   May 1, 2015                      Avengers: Age of Ultron
# 4      5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
# ...   ..           ...                                          ...
# 5777  78  Dec 31, 2018                                       Red 11
# 5778  79   Apr 2, 1999                                    Following
# 5779  80  Jul 13, 2005                Return to the Land of Wonders
# 5780  81  Sep 29, 2015                         A Plague So Pleasant
# 5781  82   Aug 5, 2005                            My Date With Drew
#
#      production_budget domestic_gross worldwide_gross  total_gross month
# 0         $425,000,000   $760,507,625  $2,776,345,279   3536852904   Dec
# ...

# %%
#to find the duplicate values
duplicates = df2.duplicated(subset=['primary_title'])
print(duplicates)
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 146139    False
# 146140    False
# 146141    False
# 146142    False
# 146143    False
# Length: 146144, dtype: bool

# %%
#combining the data in different tables to get the Return Of Investment
df_genre_ROI = df4.merge(df2[['primary_title', 'genres']], 
                           left_on='movie', 
                           right_on='primary_title', 
                           how='inner')
df_genre_ROI
# Out:
#       id  release_date                                        movie  \
# 0      1  Dec 18, 2009                                       Avatar
# 1      2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2      3   Jun 7, 2019                                 Dark Phoenix
# 3      4   May 1, 2015                      Avengers: Age of Ultron
# 4      7  Apr 27, 2018                       Avengers: Infinity War
# ...   ..           ...                                          ...
# 3810  68   Jul 6, 2001                                         Cure
# 3811  70   Apr 1, 1996                                         Bang
# 3812  73  Jan 13, 2012                                    Newlyweds
# 3813  78  Dec 31, 2018                                       Red 11
# 3814  81  Sep 29, 2015                         A Plague So Pleasant
#
#      production_budget domestic_gross worldwide_gross  total_gross month  \
# 0         $425,000,000   $760,507,625  $2,776,345,279   3536852904   Dec
# ...

# %%
#getting the insights of production budget 
df_genre_ROI['production_budget'] = df_genre_ROI['production_budget'].str.replace('[\$,]', '', regex=True).astype('int64')
df_genre_ROI['ROI'] = (df_genre_ROI['total_gross'] - df_genre_ROI['production_budget'])/df_genre_ROI['production_budget']
df_genre_ROI
# Out:
#       id  release_date                                        movie  \
# 0      1  Dec 18, 2009                                       Avatar
# 1      2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2      3   Jun 7, 2019                                 Dark Phoenix
# 3      4   May 1, 2015                      Avengers: Age of Ultron
# 4      7  Apr 27, 2018                       Avengers: Infinity War
# ...   ..           ...                                          ...
# 3810  68   Jul 6, 2001                                         Cure
# 3811  70   Apr 1, 1996                                         Bang
# 3812  73  Jan 13, 2012                                    Newlyweds
# 3813  78  Dec 31, 2018                                       Red 11
# 3814  81  Sep 29, 2015                         A Plague So Pleasant
#
#       production_budget domestic_gross worldwide_gross  total_gross month  \
# 0             425000000   $760,507,625  $2,776,345,279   3536852904   Dec
# ...

# %%
#getting the Average
df_genre_ROI_grouped = df_genre_ROI.groupby('genres')[['ROI', 'production_budget']].mean()
df_genre_ROI_grouped
# Out:
#                                  ROI  production_budget
# genres
# Action                      2.192336       3.327935e+07
# Action,Adventure            6.117365       5.369533e+07
# Action,Adventure,Animation  4.531110       1.151471e+08
# Action,Adventure,Biography  2.002105       7.100000e+07
# Action,Adventure,Comedy     4.323851       8.051515e+07
# ...                              ...                ...
# Sci-Fi,Thriller             4.772796       1.787750e+07
# Sport                       0.014255       3.066667e+07
# Thriller                    4.760740       2.592334e+07
# War                         4.519593       4.000000e+07
# Western                     0.962217       1.359375e+07
#
# [345 rows x 2 columns]

# %%
# to get the data more understandable and ROI in % format
df_genre_ROI_grouped = pd.DataFrame(df_genre_ROI_grouped)
df_genre_ROI_grouped = df_genre_ROI_grouped.reset_index()
df_genre_ROI_grouped.columns = ['Genres', 'ROI(%)', 'Budget($)']
df_sorted = df_genre_ROI_grouped.sort_values('ROI(%)', ascending=False)
df_sorted.head(20)
# Out:
#                         Genres      ROI(%)     Budget($)
# 133           Animation,Family  123.277880  3.244000e+06
# 257       Drama,Family,Fantasy   62.974088  4.895000e+07
# 26         Action,Comedy,Drama   44.105571  1.473750e+07
# 217         Crime,Drama,Family   43.981351  2.260000e+07
# 174       Comedy,Drama,Fantasy   41.926016  1.008133e+07
# 326    Horror,Romance,Thriller   38.010960  3.500000e+06
# 306             Family,Fantasy   36.217265  2.364462e+07
# 134   Animation,Family,Fantasy   36.217265  2.364462e+07
# 135  Animation,Fantasy,Musical   36.217265  2.364462e+07
# 332                    Musical   33.727223  3.053750e+07
# 50        Action,Drama,Romance   32.915999  2.496364e+07
# 324    Horror,Mystery,Thriller   32.050431  1.303106e+07
# 186             Comedy,Fantasy   31.539885  3.440000e+07
# 62          Action,History,War   30.317004  4.750000e+07
# 308     Family,Fantasy,Musical   29.122253  9.000000e+07
# ...

# %%
#according to one survey movies with >27-29% of ROI considerd as success
df_sorted['ROI(%)'] = df_sorted['ROI(%)'].astype(float)
df_sorted_goodROI = df_sorted[df_sorted['ROI(%)'] > 29]
df_sorted_goodROI
# Out:
#                         Genres      ROI(%)     Budget($)
# 133           Animation,Family  123.277880  3.244000e+06
# 257       Drama,Family,Fantasy   62.974088  4.895000e+07
# 26         Action,Comedy,Drama   44.105571  1.473750e+07
# 217         Crime,Drama,Family   43.981351  2.260000e+07
# 174       Comedy,Drama,Fantasy   41.926016  1.008133e+07
# 326    Horror,Romance,Thriller   38.010960  3.500000e+06
# 306             Family,Fantasy   36.217265  2.364462e+07
# 134   Animation,Family,Fantasy   36.217265  2.364462e+07
# 135  Animation,Fantasy,Musical   36.217265  2.364462e+07
# 332                    Musical   33.727223  3.053750e+07
# 50        Action,Drama,Romance   32.915999  2.496364e+07
# 324    Horror,Mystery,Thriller   32.050431  1.303106e+07
# 186             Comedy,Fantasy   31.539885  3.440000e+07
# 62          Action,History,War   30.317004  4.750000e+07
# 308     Family,Fantasy,Musical   29.122253  9.000000e+07

# %%
import seaborn as sns
import matplotlib.pyplot as plt

df_sorted_goodROI['Budget($)'] = df_sorted_goodROI['Budget($)'] / 1e6 

plt.figure(figsize=(18, 8))  
sns.scatterplot(data=df_sorted_goodROI, x='Budget($)', y='ROI(%)', hue='Genres', palette='tab10', s=150)

plt.xlabel('Budget($Million))') 
plt.ylabel('ROI(%)')  

plt.xticks(ticks=np.linspace(df_sorted_goodROI['Budget($)'].min(), df_sorted_goodROI['Budget($)'].max(), 10))
plt.yticks(ticks=np.linspace(df_sorted_goodROI['ROI(%)'].min(), df_sorted_goodROI['ROI(%)'].max(), 10))

plt.legend(bbox_to_anchor=(1.05, 1), loc=2)  
plt.show()
# Out:
# C:\Users\ACER\AppData\Local\Temp\ipykernel_2372\2554946531.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sorted_goodROI['Budget($)'] = df_sorted_goodROI['Budget($)'] / 1e6

# %%
# The value in genres contains multiple genres, it has to be splited for analysis by using str.split
df11 = df_sorted_goodROI['Genres'].str.split(',', expand=True).stack()
df11
# Out:
# 133  0    Animation
#      1       Family
# 257  0        Drama
#      1       Family
#      2      Fantasy
# 26   0       Action
#      1       Comedy
#      2        Drama
# 217  0        Crime
#      1        Drama
#      2       Family
# 174  0       Comedy
#      1        Drama
#      2      Fantasy
# 326  0       Horror
#      1      Romance
#      2     Thriller
# 306  0       Family
#      1      Fantasy
# 134  0    Animation
#      1       Family
#      2      Fantasy
# 135  0    Animation
#      1      Fantasy
#      2      Musical
# 332  0      Musical
# 50   0       Action
#      1        Drama
#      2      Romance
# 324  0       Horror
#      1      Mystery
#      2     Thriller
# 186  0       Comedy
#      1      Fantasy
# 62   0       Action
#      1      History
#      2          War
# 308  0       Family
#      1      Fantasy
#      2      Musical
# dtype: object

# %%
# Since the results are all the same, either of them can be used for comparison
# The value in genres contains multiple genres, it has to be split  for analysis
df2014d = df2014c.reset_index()
df12 = df2014d['genres'].str.split(',', expand=True).stack()
df12
# Out:
# 0  0      Biography
#    1    Documentary
#    2       Thriller
# 1  0    Documentary
#    1         Family
# 2  0            War
# 3  0      Animation
#    1        History
# 4  0          Drama
#    1         Family
#    2       Thriller
# 5  0      Adventure
#    1      Biography
#    2         Comedy
# 6  0      Adventure
#    1    Documentary
#    2          Sport
# 7  0    Documentary
#    1        History
#    2          Music
# 8  0        Musical
# 9  0      Adventure
#    1          Drama
#    2         Sci-Fi
# dtype: object

# %%
# now Find out the genres in common and its count
common_values = pd.Series(list(set(df11) & set(df12)))
counts = df11._append(df12).value_counts()
counts
# Out:
# Family         8
# Drama          7
# Fantasy        7
# Animation      4
# Thriller       4
# Documentary    4
# Musical        4
# Comedy         4
# History        3
# Action         3
# Adventure      3
# Horror         2
# Romance        2
# War            2
# Biography      2
# Crime          1
# Mystery        1
# Sport          1
# Music          1
# Sci-Fi         1
# Name: count, dtype: int64

# %%
#create a bar chart for the final conclusion
counts.plot(kind='bar')
plt.xticks(rotation=45)
plt.show()

# %%
#in the above bar chart it can be cocluded that top 3 genres that micro soft can invest in as follows 
#Drama-Fantasy ,Family and musical documentary animation comedy 
#released in the months of may,june,july,november,december
#by looking all the above insights the microsoft should invest in the range of 15-35 million on the above top 3 genres like family animation,family fantasy,
#action
